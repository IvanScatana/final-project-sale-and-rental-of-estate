# %% [markdown]
# # удаляем: тип, адрес, телефон, описание, серия, название ЖК

# %% [markdown]
# # количество комнат:
# 1) количество комнат
# 2) изолированные
# 3) смежные

# %% [markdown]
# # метро:
# 1) количество минут до метро
# 2) тип
#
# 1) количство минут до метро пешком
# 2) количство минут до метро машине
# 3) тип пешком
# 4) на машине пешком

# %% [markdown]
# плащадь
